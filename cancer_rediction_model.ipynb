# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DATA/cancer_classification.csv')

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x='benign_0__mal_1', data=df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
df.corr()['benign_0__mal_1'].sort_values()
# Out:
# worst concave points      -0.793566
# worst perimeter           -0.782914
# mean concave points       -0.776614
# worst radius              -0.776454
# mean perimeter            -0.742636
# worst area                -0.733825
# mean radius               -0.730029
# mean area                 -0.708984
# mean concavity            -0.696360
# worst concavity           -0.659610
# mean compactness          -0.596534
# worst compactness         -0.590998
# radius error              -0.567134
# perimeter error           -0.556141
# area error                -0.548236
# worst texture             -0.456903
# worst smoothness          -0.421465
# worst symmetry            -0.416294
# mean texture              -0.415185
# concave points error      -0.408042
# mean smoothness           -0.358560
# mean symmetry             -0.330499
# worst fractal dimension   -0.323872
# compactness error         -0.292999
# concavity error           -0.253730
# fractal dimension error   -0.077972
# ...

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
X = df.drop('benign_0__mal_1', axis=1).values
y= df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense, Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

# Binary Classification use sigmoid for activation
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test, y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 37ms/step - loss: 0.6564 - val_loss: 0.6322
# Epoch 2/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6157 - val_loss: 0.5894
# Epoch 3/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5748 - val_loss: 0.5428
# Epoch 4/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5268 - val_loss: 0.4948
# Epoch 5/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4779 - val_loss: 0.4385
# Epoch 6/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4267 - val_loss: 0.3864
# Epoch 7/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3804 - val_loss: 0.3437
# Epoch 8/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3417 - val_loss: 0.3056
# Epoch 9/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3097 - val_loss: 0.2764
# Epoch 10/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))

# Binary Classification use sigmoid for activation
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 28ms/step - loss: 0.6752 - val_loss: 0.6554
# Epoch 2/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6332 - val_loss: 0.6126
# Epoch 3/600
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5926 - val_loss: 0.5692
# Epoch 4/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5508 - val_loss: 0.5234
# Epoch 5/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5037 - val_loss: 0.4746
# Epoch 6/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.4568 - val_loss: 0.4278
# Epoch 7/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.4118 - val_loss: 0.3832
# Epoch 8/600
# 14/14 [==============================] - 0s 8ms/step - loss: 0.3733 - val_loss: 0.3451
# Epoch 9/600
# 14/14 [==============================] - 0s 10ms/step - loss: 0.3402 - val_loss: 0.3132
# Epoch 10/600
# ...

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(15, activation='relu'))
model.add(Dropout(0.5))

# Binary Classification use sigmoid for activation
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.layers import Dropout

# %%
model.fit(x=X_train, y=y_train, epochs=600, validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 2s 38ms/step - loss: 0.6756 - val_loss: 0.6614
# Epoch 2/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.6616 - val_loss: 0.6423
# Epoch 3/600
# 14/14 [==============================] - 0s 15ms/step - loss: 0.6323 - val_loss: 0.6241
# Epoch 4/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6374 - val_loss: 0.6064
# Epoch 5/600
# 14/14 [==============================] - 0s 11ms/step - loss: 0.6086 - val_loss: 0.5869
# Epoch 6/600
# 14/14 [==============================] - 0s 21ms/step - loss: 0.6104 - val_loss: 0.5668
# Epoch 7/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5848 - val_loss: 0.5415
# Epoch 8/600
# 14/14 [==============================] - 0s 12ms/step - loss: 0.5631 - val_loss: 0.5158
# Epoch 9/600
# 14/14 [==============================] - 0s 13ms/step - loss: 0.5358 - val_loss: 0.4919
# Epoch 10/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %%
predictions = (model.predict(X_test) > 0.5).astype("int32") #work for binary classification

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97        55
#            1       0.99      0.98      0.98        88
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.98      0.98       143
# weighted avg       0.98      0.98      0.98       143

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[54  1]
#  [ 2 86]]
